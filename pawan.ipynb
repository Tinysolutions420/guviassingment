# %% [markdown]
# <a href="https://colab.research.google.com/github/Tinysolutions420/guviassingment/blob/main/pawan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install dnspython
# !pip install pymongo[srv]
# Out:
# Requirement already satisfied: dnspython in /usr/local/lib/python3.7/dist-packages (2.2.1)
# Requirement already satisfied: pymongo[srv] in /usr/local/lib/python3.7/dist-packages (4.0.2)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from pymongo[srv]) (2.2.1)

# %%
import pymongo

client = pymongo.MongoClient("mongodb+srv://pawankalyan:Kingsrule#2002@cluster0.icyej.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client.dw9

records=db.guvi

# %%
dict2={
    "name":"pawan",
    "id":19,
    "age":34
}
records.insert_one(dict2)

# %%
mylist = [
  {'name':'pawan','address':'chennai'},
  {'name':'p1','address':'hyd'},
  {'name':'p2','address':'goa'},
  {'_id':'pawankalyansankara.com','name':'pawan','address':'iitm'}
]

x=records.insert_many(mylist)
print(x.inserted_ids)
# Out:
# ---------------------------------------------------------------------------
# BulkWriteError                            Traceback (most recent call last)
# <ipython-input-14-e82fdd964e62> in <module>()
#       6 ]
#       7
# ----> 8 x=records.insert_many(mylist)
#       9 print(x.inserted_ids)
#
# /usr/local/lib/python3.7/dist-packages/pymongo/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     613         blk = _Bulk(self, ordered, bypass_document_validation)
#     614         blk.ops = [doc for doc in gen()]
# --> 615         blk.execute(write_concern, session=session)
#     616         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     617
#
# /usr/local/lib/python3.7/dist-packages/pymongo/bulk.py in execute(self, write_concern, session)
#     457                 self.execute_no_results(sock_info, generator)
#     458         else:
# --> 459             return self.execute_command(generator, write_concern, session)
#
# /usr/local/lib/python3.7/dist-packages/pymongo/bulk.py in execute_command(self, generator, write_concern, session)
#     353
#     354         if full_result["writeErrors"] or full_result["writeConcernErrors"]:
# --> 355             _raise_bulk_write_error(full_result)
#     356         return full_result
#     357
#
# /usr/local/lib/python3.7/dist-packages/pymongo/bulk.py in _raise_bulk_write_error(full_result)
#     133     if full_result["writeErrors"]:
#     134         full_result["writeErrors"].sort(key=lambda error: error["index"])
# --> 135     raise BulkWriteError(full_result)
#     136
#     137
#
# BulkWriteError: batch op errors occurred, full error: {'writeErrors': [{'index': 3, 'code': 11000, 'keyPattern': {'_id': 1}, 'keyValue': {'_id': 'pawankalyansankara.com'}, 'errmsg': 'E11000 duplicate key error collection: dw9.guvi index: _id_ dup key: { _id: "pawankalyansankara.com" }', 'op': {'_id': 'pawankalyansankara.com', 'name': 'pawan', 'address': 'iitm'}}], 'writeConcernErrors': [], 'nInserted': 3, 'nUpserted': 0, 'nMatched': 0, 'nModified': 0, 'nRemoved': 0, 'upserted': []}

# %%
dict2={
    'name': input(),
    'age': input(),
    'mailid': input(),
    'phoneno': input()
}
a=records.insert_one(dict2)
if a != None:
  print('inserted dude')
else:
  print('bad luck buddy')
# Out:
# pawan
# 19
# pawankalyansnkara2002@gmail.com
# 0090099
# inserted dude

# %%
import json
x='{"name":"yash","age":"30","city":"KGF"}'
y=json.loads(x)
print(y)
print(y["city"])
# Out:
# {'name': 'yash', 'age': '30', 'city': 'KGF'}
# KGF

# %%
from IPython.lib.display import YouTubeVideo
x={"name":"yash","age":"30","city":"KGF"}
y=json.dumps(x)
y
# Out:
# '{"name": "yash", "age": "30", "city": "KGF"}'

# %%
# !pip install pillow
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (7.1.2)

# %%
from pymongo import MongoClient
from PIL import Image
import io
client = pymongo.MongoClient("mongodb+srv://pawankalyan:Kingsrule#2002@cluster0.icyej.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client.dw9
images=db.images
im=Image.open("/content/rrr.png")
image_bytes=io.BytesIO()
im.save(image_bytes,format='png')
image={
    "name":"pawan",
    "image":image_bytes.getvalue()
}

image_id=images.insert_one(image)

# %%
from PIL import Image

im = Image.open("/content/rrr.png")
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1590x859 at 0x7FF049279F90>

# %%
from pymongo import MongoClient
from PIL import Image
import io
import matplotlib.pyplot as plt
client = pymongo.MongoClient("mongodb+srv://pawankalyan:Kingsrule#2002@cluster0.icyej.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client.dw9
images=db.images

image=images.find_one({'name':'pawan'})

pil_img = Image.open(io.BytesIO(image['image']))
pil_img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1590x859 at 0x7FF049289C10>

# %%
import re
import os
import json



def Registration():
  email=input("Enter the Email for registration:")
  regex1 = '^[A-Za-z0-9]+[@]\w+[.]\w{2,3}$'
  if(re.search  (regex1, email)):
    pw=input("Enter the Password for registraion:")
    regex2 = "^.*(?=.{6,15})(?=.*\d)(?=.*[a-z])(?=.*[A-Z])(?=.*[@#$%^&+=]).*$"
    if(re.findall(regex2, pw)):
        print("Valid Email and Password")
        Dic1={email:pw}
        path = '/content/pawan.txt'
        isExist = os.path.exists(path)
        if isExist is False:
          f = open("pawan.txt", "w")
          f.write(json.dumps(Dic1))
          f.close()
          print("Registration Successful")
    
        else:
          f = open("pawan.txt", "r")
          filecontents = f.read()
          x = json.loads(filecontents)
          f.close()
          x.update(Dic1)
          f = open("pk.txt", "w")
          f.write(json.dumps(x))
          f.close()
          print("Registration Successful")   
    else:
      print("Invalid Password, make sure the following conditions are satisfied:"
      "\n Your password must have:"
      "\n   one special character"
      "\n   one digit"
      "\n   one uppercase"
      "\n   one lowercase character")
  else:
    print("Invalid Username, make sure the following conditions are satisfied:" 
    "\n Username should have @ and followed by ." 
    "\n There should not be any . immediate next to @" 
    "\n It should not start with special characters and numbers")




def Retrive_Password():
  Forgotpass_Email=input("Enter your email to retrieve your password: ")
  f=open("pawan.txt","r")
  filecontents=f.read()
  x=json.loads(filecontents)
  f.close()
  if(Forgotpass_Email in x.keys()):
    print("The Password for your email is: ",x[Forgotpass_Email])
  else:
    print("Go and Register")

def Login():
  Login_Email = input("Enter your login email ")

  f = open("pk.txt", "r")
  filecontents = f.read()
  x = json.loads(filecontents)
  f.close()
  if (Login_Email not in x.keys()):
    print("Your email is not registered, please Register first and then Login")
  else:
    Login_Password = input("Enter your login password ")
    if (x[Login_Email] == Login_Password):
      print("Login Successful")
    else:
      print("Forgot Password? Please provide the email ID to retrieve the password")
      

ini1=input("Enter 1 for Registraion \nEnter 2 for Login\nEnter 3 Retrive_Password \n")
if ini1=="1":
  Registration()

elif ini1=="2":
  Login()

elif ini1=="3":
  Retrive_Password()
    
else:
  print("Ener a valid option")
# Out:
# Enter 1 for Registraion
# Enter 2 for Login
# Enter 3 Retrive_Password
# 1
# Enter the Email for registration:pawankalyansankara2002@gmail.com
# Enter the Password for registraion:Kingsrule#2002
# Valid Email and Password
# Registration Successful

# %%
for x in records.find():
  print(x)
# Out:
# {'_id': ObjectId('624ee103ecfe206a4c567e5e'), 'name': 'pawan', 'id': 19, 'age': 34}
# {'_id': ObjectId('624ee106ecfe206a4c567e5f'), 'name': 'pawan', 'address': 'chennai'}
# {'_id': ObjectId('624ee106ecfe206a4c567e60'), 'name': 'p1', 'address': 'hyd'}
# {'_id': ObjectId('624ee106ecfe206a4c567e61'), 'name': 'p2', 'address': 'goa'}
# {'_id': 'pawankalyansankara.com', 'name': 'pawan', 'address': 'iitm'}
# {'_id': ObjectId('624ee24fecfe206a4c567e62'), 'name': 'rishi ', 'age': '19', 'mailid': 'pawankalyansankara2002@gmail.com', 'phoneno': '9090900909'}
# {'_id': ObjectId('625039d836c94951a3c3eeaa'), 'name': 'pawan', 'id': 19, 'age': 34}
# {'_id': ObjectId('625039dd36c94951a3c3eeab'), 'name': 'pawan', 'address': 'chennai'}
# {'_id': ObjectId('625039dd36c94951a3c3eeac'), 'name': 'p1', 'address': 'hyd'}
# {'_id': ObjectId('625039dd36c94951a3c3eead'), 'name': 'p2', 'address': 'goa'}
# {'_id': ObjectId('62503a0376618ed47f6742b1'), 'name': 'pawan', 'id': 19, 'age': 34}
# {'_id': ObjectId('62503a0576618ed47f6742b2'), 'name': 'pawan', 'address': 'chennai'}
# {'_id': ObjectId('62503a0576618ed47f6742b3'), 'name': 'p1', 'address': 'hyd'}
# {'_id': ObjectId('62503a0576618ed47f6742b4'), 'name': 'p2', 'address': 'goa'}
# {'_id': ObjectId('62503a1d76618ed47f6742b5'), 'name': 'pawan', 'address': 'chennai'}
# {'_id': ObjectId('62503a1d76618ed47f6742b6'), 'name': 'p1', 'address': 'hyd'}
# {'_id': ObjectId('62503a1d76618ed47f6742b7'), 'name': 'p2', 'address': 'goa'}
# {'_id': ObjectId('62503a3c76618ed47f6742b8'), 'name': 'pawan', 'age': '19', 'mailid': 'pawankalyansnkara2002@gmail.com', 'phoneno': '0090099'}
# {'_id': ObjectId('62503a9676618ed47f6742bd'), 'name': 'pawan', 'address': 'chennai'}
# {'_id': ObjectId('62503a9676618ed47f6742be'), 'name': 'p1', 'address': 'hyd'}
# {'_id': ObjectId('62503a9676618ed47f6742bf'), 'name': 'p2', 'address': 'goa'}
